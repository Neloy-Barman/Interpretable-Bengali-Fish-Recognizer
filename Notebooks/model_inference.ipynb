# %% [markdown]
# ## **Installing necessary packages**

# %%
# !pip install -Uqq fastai fastbook nbdev
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.1/66.1 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 38.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.9 MB/s eta 0:00:00

# %% [markdown]
# ## **Using required imports and magic functions**

# %%
import warnings
from fastai import *
from fastbook import *
from fastai.vision.all import *
warnings.filterwarnings('ignore')
from fastai.vision.widgets import *

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## **Mounting Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Intializing project folder path**

# %%
# %cd /content/drive/MyDrive/Bengali Fish Recognizer
# Out:
# /content/drive/MyDrive/Bengali Fish Recognizer

# %% [markdown]
# ## **Loading the model file**

# %%
model = load_learner("models/VGG19_1.pkl")

# %% [markdown]
# ## **Inference 1**

# %%
image_1_path = "test images/unknown_01.jpg"
image_1 = Image.open(image_1_path)
image_1.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGBA size=224x168>

# %%
model.predict(image_1_path) # Wrong Prediction
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Catla',
#  tensor(1),
#  tensor([8.6996e-08, 8.6691e-01, 2.9466e-07, 9.4168e-07, 2.9215e-06, 9.7139e-07, 3.9944e-06, 6.0770e-09, 1.5365e-06, 1.9584e-05, 1.7970e-08, 6.6814e-06, 1.8020e-06, 2.0578e-07, 1.3304e-01, 1.9332e-07,
#          2.7683e-06, 7.8325e-08, 6.0428e-07, 5.1189e-08]))

# %% [markdown]
# ## **Inference 2**

# %%
image_2_path = "test images/unknown_02.png"
image_2 = Image.open(image_2_path)
image_2.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGBA size=224x134>

# %%
model.predict(image_2_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Catla',
#  tensor(1),
#  tensor([4.0383e-10, 1.0000e+00, 1.6271e-11, 1.4154e-10, 6.9404e-11, 3.3280e-09, 2.5282e-09, 3.6014e-12, 3.9237e-08, 3.1000e-09, 2.7460e-11, 2.2263e-08, 6.6842e-10, 5.6408e-11, 3.1838e-07, 4.0974e-11,
#          5.0635e-09, 4.5354e-12, 6.5285e-09, 2.3714e-10]))

# %% [markdown]
# ## **Inference 3**

# %%
image_3_path = "test images/unknown_03.jpg"
image_3 = Image.open(image_3_path)
image_3.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=187x224>

# %%
model.predict(image_3_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Tengra',
#  tensor(19),
#  tensor([2.4230e-04, 1.1852e-03, 1.5020e-08, 1.8069e-02, 3.9058e-04, 3.1232e-06, 4.7329e-06, 1.2458e-07, 1.2997e-04, 2.1398e-05, 8.4554e-06, 4.9518e-04, 6.9532e-06, 2.8111e-04, 5.7410e-06, 4.9882e-08,
#          1.1551e-06, 8.8332e-09, 2.7070e-08, 9.7916e-01]))

# %% [markdown]
# ## **Inference 4**

# %%
image_4_path = "test images/unknown_04.jpg"
image_4 = Image.open(image_4_path)
image_4.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x150>

# %%
model.predict(image_4_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Pabda',
#  tensor(10),
#  tensor([1.3713e-06, 7.7208e-06, 4.8790e-06, 6.7046e-03, 1.1093e-04, 5.6728e-05, 8.8436e-08, 1.2829e-05, 5.3900e-05, 3.1719e-07, 9.9074e-01, 2.0539e-06, 2.2596e-03, 2.4792e-06, 2.4503e-05, 6.3996e-07,
#          1.4589e-07, 7.5281e-08, 1.1003e-06, 1.5364e-05]))

# %% [markdown]
# ## **Inference 5**

# %%
image_5_path = "test images/unknown_05.jpg"
image_5 = Image.open(image_5_path)
image_5.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
model.predict(image_5_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Shing',
#  tensor(15),
#  tensor([1.1801e-09, 7.8844e-09, 3.5802e-07, 1.0510e-08, 6.4752e-09, 1.9284e-07, 7.7994e-07, 1.2253e-06, 1.0230e-08, 1.2475e-08, 6.8991e-07, 3.0410e-09, 3.1304e-09, 6.4004e-09, 4.5091e-09, 1.0000e+00,
#          3.1791e-09, 8.7087e-07, 8.8593e-11, 3.7985e-09]))

# %% [markdown]
# ## **Inference 6**

# %%
image_6_path = "test images/unknown_06.jpg"
image_6 = Image.open(image_6_path)
image_6.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=199x224>

# %%
model.predict(image_6_path) # Wrong Prediction
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Catla',
#  tensor(1),
#  tensor([5.7699e-07, 7.6651e-01, 1.7450e-06, 5.0921e-05, 5.0949e-05, 3.5403e-05, 5.3799e-06, 3.5271e-06, 1.6122e-05, 8.2807e-03, 8.0434e-07, 1.8726e-05, 8.8793e-05, 2.0449e-05, 2.2486e-01, 1.6169e-06,
#          1.3092e-06, 9.2344e-08, 2.3636e-06, 5.3681e-05]))

# %% [markdown]
# ## **Inference 7**

# %%
image_7_path = "test images/unknown_07.jpg"
image_7 = Image.open(image_7_path)
image_7.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
model.predict(image_7_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Poa',
#  tensor(12),
#  tensor([1.7444e-06, 5.2818e-04, 5.0923e-03, 1.4717e-03, 1.0013e-03, 7.9819e-05, 1.6579e-05, 8.8679e-03, 2.0522e-03, 3.2060e-05, 7.1771e-03, 7.6776e-05, 9.5444e-01, 1.4427e-04, 6.0626e-03, 9.2074e-03,
#          3.5229e-03, 9.4093e-05, 1.2887e-04, 2.3681e-06]))

# %% [markdown]
# ## **Inference 8**

# %%
image_8_path = "test images/unknown_08.jpg"
image_8 = Image.open(image_8_path)
image_8.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
model.predict(image_8_path) # Wrong Prediction
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Mrigal',
#  tensor(9),
#  tensor([7.5805e-06, 1.8741e-03, 1.8249e-06, 6.8475e-03, 1.1009e-01, 3.6495e-06, 1.0661e-03, 4.8468e-07, 2.0407e-03, 4.7957e-01, 5.6367e-05, 6.1645e-05, 2.9562e-03, 3.7120e-01, 2.3632e-02, 3.1854e-08,
#          5.4285e-04, 5.1821e-06, 8.1990e-06, 3.0422e-05]))

# %% [markdown]
# ## **Inference 9**

# %%
image_9_path = "test images/unknown_09.jpg"
image_9 = Image.open(image_9_path)
image_9.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=199x224>

# %%
model.predict(image_9_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Magur',
#  tensor(7),
#  tensor([1.1646e-03, 6.5788e-05, 5.4479e-05, 6.7794e-03, 4.9315e-04, 2.1744e-03, 4.2340e-02, 4.7970e-01, 3.6864e-05, 2.6841e-03, 6.6280e-02, 2.2141e-04, 5.9392e-03, 3.9197e-04, 1.9734e-05, 2.6696e-01,
#          1.7454e-05, 1.2035e-02, 4.3472e-05, 1.1259e-01]))

# %% [markdown]
# ## **Inference 10**

# %%
image_10_path = "test images/unknown_10.jpg"
image_10 = Image.open(image_10_path)
image_10.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
model.predict(image_10_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Koi',
#  tensor(6),
#  tensor([6.4016e-03, 6.8094e-03, 1.1437e-04, 4.6418e-03, 5.7951e-04, 2.1317e-03, 4.6449e-01, 5.1378e-03, 1.2935e-03, 5.2501e-03, 4.8783e-03, 5.0038e-06, 2.6459e-01, 3.4739e-02, 4.7133e-03, 1.6329e-03,
#          1.6276e-04, 1.7482e-01, 1.6797e-02, 8.1401e-04]))

# %% [markdown]
# ## **Inference 11**

# %%
image_11_path = "test images/unknown_11.jpg"
image_11 = Image.open(image_11_path)
image_11.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x90>

# %%
model.predict(image_11_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Chital',
#  tensor(2),
#  tensor([6.1738e-08, 4.8858e-10, 9.9993e-01, 5.4670e-08, 7.2109e-07, 4.3230e-08, 2.1547e-10, 1.0506e-07, 5.5953e-07, 6.7709e-10, 2.0252e-08, 7.2164e-05, 2.2382e-10, 4.5261e-10, 1.9630e-09, 4.4028e-09,
#          9.4627e-09, 7.9517e-09, 1.3282e-10, 2.0618e-11]))
