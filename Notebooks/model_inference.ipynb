# %% [markdown]
# ## **Installing necessary packages**

# %%
# !pip install -Uqq fastai fastbook nbdev

# %% [markdown]
# ## **Using required imports and magic functions**

# %%
import warnings
from fastai import *
from fastbook import *
from fastai.vision.all import *
warnings.filterwarnings('ignore')
from fastai.vision.widgets import *

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## **Mounting Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Intializing project folder path**

# %%
# %cd /content/drive/MyDrive/Bengali Fish Recognizer
# Out:
# /content/drive/MyDrive/Bengali Fish Recognizer

# %% [markdown]
# ## **Loading the model file**

# %%
model = load_learner("models/ResNet50_1.pkl")

# %% [markdown]
# ## **Inference 1**

# %%
image_1_path = "test images/unknown_01.jpg"
image_1 = Image.open(image_1_path)
image_1.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGBA size=224x168>

# %%
model.predict(image_1_path) # Wrong Prediction
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Rui',
#  tensor(14),
#  tensor([2.3045e-07, 1.4935e-02, 1.9651e-07, 2.4329e-05, 4.0959e-05, 2.1907e-06, 3.0818e-05, 2.6259e-08, 9.5408e-05, 5.3666e-04, 1.1866e-08, 2.8513e-05, 2.5744e-05, 1.7494e-04, 9.8409e-01, 2.7755e-07,
#          1.0989e-05, 1.4110e-07, 1.2054e-06, 2.0943e-06]))

# %% [markdown]
# ## **Inference 2**

# %%
image_2_path = "test images/unknown_02.png"
image_2 = Image.open(image_2_path)
image_2.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGBA size=224x134>

# %%
model.predict(image_2_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Catla',
#  tensor(1),
#  tensor([3.1480e-06, 9.9415e-01, 7.5244e-08, 2.2433e-07, 7.7627e-07, 8.0922e-07, 1.5744e-06, 4.7253e-08, 3.4118e-08, 7.4397e-05, 5.2557e-09, 2.1932e-06, 1.3023e-07, 9.7860e-07, 5.7533e-03, 3.1103e-08,
#          3.8756e-07, 1.3132e-08, 1.0780e-05, 1.0066e-07]))

# %% [markdown]
# ## **Inference 3**

# %%
image_3_path = "test images/unknown_03.jpg"
image_3 = Image.open(image_3_path)
image_3.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=187x224>

# %%
model.predict(image_3_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Tengra',
#  tensor(19),
#  tensor([1.0515e-03, 1.8447e-08, 1.4042e-10, 2.0837e-08, 1.4480e-09, 1.9848e-07, 4.2804e-09, 1.8398e-09, 1.8292e-08, 1.2052e-06, 6.8689e-08, 5.5470e-09, 1.7004e-06, 3.3753e-09, 5.5534e-11, 9.4852e-08,
#          1.0024e-07, 9.8109e-10, 1.8103e-08, 9.9895e-01]))

# %% [markdown]
# ## **Inference 4**

# %%
image_4_path = "test images/unknown_04.jpg"
image_4 = Image.open(image_4_path)
image_4.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x150>

# %%
model.predict(image_4_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Pabda',
#  tensor(10),
#  tensor([5.7446e-05, 1.3883e-03, 5.0068e-06, 3.7574e-04, 2.5763e-03, 8.4293e-02, 4.0110e-06, 5.3604e-05, 3.8659e-04, 3.0704e-03, 8.8891e-01, 9.2453e-03, 8.8043e-03, 7.1732e-05, 3.1973e-04, 9.3136e-05,
#          1.1298e-04, 2.5028e-05, 1.0808e-05, 1.9585e-04]))

# %% [markdown]
# ## **Inference 5**

# %%
image_5_path = "test images/unknown_05.jpg"
image_5 = Image.open(image_5_path)
image_5.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
model.predict(image_5_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Shing',
#  tensor(15),
#  tensor([2.9437e-07, 2.9968e-08, 3.8256e-08, 1.1360e-08, 7.9385e-07, 3.1218e-06, 1.9904e-05, 1.6613e-03, 7.7666e-09, 7.5519e-06, 6.7924e-06, 7.9200e-07, 4.2433e-06, 1.1338e-08, 1.1650e-05, 9.9828e-01,
#          1.5861e-07, 3.0650e-06, 1.2663e-08, 8.3264e-07]))

# %% [markdown]
# ## **Inference 6**

# %%
image_6_path = "test images/unknown_06.jpg"
image_6 = Image.open(image_6_path)
image_6.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=199x224>

# %%
model.predict(image_6_path) # Wrong Prediction
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Catla',
#  tensor(1),
#  tensor([2.2695e-06, 8.4057e-01, 1.8121e-05, 3.2811e-04, 1.6295e-05, 1.7024e-04, 2.2037e-03, 4.6429e-06, 1.5138e-04, 1.7646e-02, 1.3358e-06, 1.1149e-03, 6.8957e-04, 6.1639e-04, 1.3604e-01, 1.0206e-05,
#          1.6558e-05, 7.9760e-07, 3.8870e-04, 1.1585e-06]))

# %% [markdown]
# ## **Inference 7**

# %%
image_7_path = "test images/unknown_07.jpg"
image_7 = Image.open(image_7_path)
image_7.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
model.predict(image_7_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Poa',
#  tensor(12),
#  tensor([1.5646e-05, 3.4748e-04, 2.0127e-05, 5.1834e-04, 7.6698e-06, 6.2635e-05, 4.5790e-05, 9.3824e-05, 2.2454e-04, 2.2801e-05, 2.6792e-05, 4.0586e-05, 9.9778e-01, 3.2012e-06, 4.3387e-05, 5.6258e-06,
#          1.7084e-04, 6.3852e-06, 5.2581e-04, 3.8403e-05]))

# %% [markdown]
# ## **Inference 8**

# %%
image_8_path = "test images/unknown_08.jpg"
image_8 = Image.open(image_8_path)
image_8.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
model.predict(image_8_path) # Wrong Prediction
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Rui',
#  tensor(14),
#  tensor([1.4682e-04, 3.1245e-01, 1.6536e-05, 5.1143e-03, 4.9284e-03, 6.8614e-04, 2.1405e-02, 8.1692e-05, 6.3069e-02, 5.2500e-02, 1.1460e-04, 2.4056e-02, 6.9683e-04, 1.0353e-01, 4.0268e-01, 5.6716e-05,
#          3.2460e-04, 1.2264e-05, 2.5443e-03, 5.5894e-03]))

# %% [markdown]
# ## **Inference 9**

# %%
image_9_path = "test images/unknown_09.jpg"
image_9 = Image.open(image_9_path)
image_9.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=199x224>

# %%
model.predict(image_9_path) # Wrong Prediction
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Koi',
#  tensor(6),
#  tensor([9.4746e-04, 6.2739e-04, 5.0735e-05, 1.8703e-03, 8.0586e-05, 1.7774e-04, 5.9964e-01, 2.1433e-02, 2.6028e-04, 1.1093e-03, 6.3264e-03, 3.8759e-05, 6.5040e-02, 5.2927e-04, 2.6828e-04, 1.8890e-01,
#          3.1776e-06, 1.9152e-02, 7.4260e-02, 1.9280e-02]))

# %% [markdown]
# ## **Inference 10**

# %%
image_10_path = "test images/unknown_10.jpg"
image_10 = Image.open(image_10_path)
image_10.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
model.predict(image_10_path) # Wrong Prediction
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Telapia',
#  tensor(18),
#  tensor([9.1615e-05, 1.4765e-02, 1.1221e-04, 2.0610e-02, 4.4064e-05, 3.1064e-05, 4.8078e-02, 1.6759e-03, 1.7759e-03, 3.4998e-04, 3.3679e-04, 1.1234e-05, 1.3330e-02, 1.4497e-02, 2.4766e-03, 1.2494e-03,
#          2.8520e-05, 9.6472e-03, 8.7084e-01, 4.8072e-05]))

# %% [markdown]
# ## **Inference 11**

# %%
image_11_path = "test images/unknown_11.jpg"
image_11 = Image.open(image_11_path)
image_11.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x90>

# %%
model.predict(image_11_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Chital',
#  tensor(2),
#  tensor([7.8811e-09, 5.7366e-08, 9.9999e-01, 1.9105e-07, 7.9960e-07, 1.2656e-06, 1.3012e-10, 1.3857e-07, 6.5109e-08, 1.3557e-09, 1.9152e-06, 6.2108e-06, 5.6697e-09, 1.0001e-09, 7.3020e-10, 1.8022e-07,
#          6.2978e-08, 1.5449e-09, 9.1561e-11, 3.2214e-10]))

# %% [markdown]
# ## **Inference 12**

# %%
image_12_path = "test images/unknown_12.png"
image_12 = Image.open(image_12_path)
image_12.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x128>

# %%
model.predict(image_12_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Telapia',
#  tensor(18),
#  tensor([3.8705e-07, 9.3207e-06, 8.7702e-08, 1.3371e-06, 5.1700e-09, 1.8166e-08, 1.5447e-04, 8.9423e-07, 7.4788e-08, 9.2132e-08, 5.0585e-10, 1.0501e-07, 4.4430e-06, 3.1053e-08, 4.8734e-06, 3.4324e-08,
#          1.0489e-07, 1.7563e-07, 9.9982e-01, 8.6456e-10]))

# %% [markdown]
# ## **Inference 13**

# %%
image_13_path = "test images/unknown_13.jpg"
image_13 = Image.open(image_13_path)
image_13.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x149>

# %%
model.predict(image_13_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Taki',
#  tensor(17),
#  tensor([2.4611e-04, 4.6535e-05, 5.2392e-05, 1.5713e-04, 1.2361e-04, 9.8279e-06, 2.4737e-03, 7.1638e-03, 1.8865e-05, 3.3779e-05, 2.9835e-04, 1.5587e-04, 2.1737e-02, 5.7628e-06, 1.9045e-04, 1.1338e-05,
#          3.6276e-06, 9.6631e-01, 8.9198e-04, 6.8488e-05]))

# %% [markdown]
# ## **Inference 14**

# %%
image_14_path = "test images/unknown_14.png"
image_14 = Image.open(image_14_path)
image_14.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGBA size=224x224>

# %%
model.predict(image_14_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Pangash',
#  tensor(11),
#  tensor([1.1117e-06, 2.7456e-06, 5.8170e-08, 3.7308e-06, 1.3640e-05, 5.7846e-05, 3.1258e-06, 8.6497e-09, 8.0970e-06, 3.1591e-05, 2.0234e-06, 9.9729e-01, 1.9855e-07, 7.2991e-06, 2.5772e-03, 1.0995e-07,
#          8.1882e-07, 1.5401e-09, 2.4208e-07, 2.2887e-06]))

# %% [markdown]
# ## **Inference 15**

# %%
image_15_path = "test images/unknown_15.png"
image_15 = Image.open(image_15_path)
image_15.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGBA size=224x134>

# %%
model.predict(image_15_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Silver Carp',
#  tensor(16),
#  tensor([3.7153e-12, 8.2331e-10, 5.7442e-08, 1.7321e-07, 6.0123e-09, 2.0478e-09, 6.7405e-11, 1.5084e-10, 1.5957e-07, 2.2718e-09, 8.0672e-11, 1.3353e-06, 3.6525e-08, 6.2940e-10, 5.8981e-09, 5.0467e-11,
#          1.0000e+00, 4.2749e-12, 1.0343e-09, 8.8773e-12]))

# %% [markdown]
# ## **Inference 16**

# %%
image_16_path = "test images/unknown_16.png"
image_16 = Image.open(image_16_path)
image_16.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGBA size=224x134>

# %%
model.predict(image_16_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Ayre',
#  tensor(0),
#  tensor([9.9503e-01, 6.0565e-05, 5.5964e-08, 6.0369e-05, 2.4683e-07, 8.7796e-06, 2.1964e-06, 4.1749e-05, 1.2817e-06, 3.2250e-06, 9.9216e-06, 2.9424e-03, 6.7355e-06, 1.2944e-07, 3.8675e-05, 4.2703e-05,
#          1.4488e-05, 1.8257e-06, 1.0278e-06, 1.7347e-03]))

# %% [markdown]
# ## **Inference 17**

# %%
image_17_path = "test images/unknown_17.jpg"
image_17 = Image.open(image_17_path)
image_17.to_thumb(224,224)
# Out:
# <PIL.Image.Image image mode=RGB size=187x224>

# %%
model.predict(image_17_path) # Wrong Prediction
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Silver Carp',
#  tensor(16),
#  tensor([4.8725e-08, 1.3645e-04, 8.5430e-07, 1.0196e-03, 1.3227e-05, 4.1942e-06, 3.4846e-07, 1.0926e-08, 1.4771e-03, 5.3950e-04, 2.8680e-06, 4.2750e-04, 5.1327e-06, 1.8578e-05, 7.7047e-07, 4.5539e-08,
#          9.9630e-01, 1.7680e-07, 2.7030e-07, 5.7860e-05]))
